# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15,9]
df = pd.read_csv('data/crypto.csv')
dfsd = df.groupby(['Asset_Name'])["Close"].std().to_frame()
dfsd.plot(kind = "bar")
# Out:
# <Axes: xlabel='Asset_Name'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15,9]
df = pd.read_csv('data/crypto.csv', parse_dates=[1])
period = int(input("Enter a number to indicate the number of days in average: "))
ethereum = df[df['Asset_Name'] == 'Ethereum'].copy()
ethereum["Rolling"] = ethereum['Close'].rolling(period).mean()
plt.plot(ethereum['timestamp'], ethereum['Rolling'])
plt.show()
