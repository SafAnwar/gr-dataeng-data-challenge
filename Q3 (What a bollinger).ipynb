# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15,9]
df = pd.read_csv('data/crypto.csv')
dfsd = df.groupby(['Asset_Name'])["Close"].std().to_frame()
dfsd.plot(kind = "bar")
# Out:
# <Axes: xlabel='Asset_Name'>

# %%
ethereum = df[df['Asset_Name'] == 'Ethereum']
period = int(input("Enter a number to indicate the number of days in average: "))
ethereum = ethereum[["Close", "timestamp"]].copy()
ethereum["SPA"] = ethereum["Close"].rolling(period).std()
ethereum.dropna(inplace = True)
ethereum.head()
ethereum.set_index("timestamp")[["SPA"]].plot(label = "Ethereum", figsize=(15,9))
# Out:
# Enter a number to indicate the number of days in average:  7
# <Axes: xlabel='timestamp'>
